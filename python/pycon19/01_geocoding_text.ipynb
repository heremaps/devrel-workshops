# %% [markdown]
# # Analyzing Text
#
# It may be surprising that not all travel articles include a map.  Understanding where restaurants, hotels, landmarks, and other points of interest are in relation to each other is important for itinerary building.Parsing text to look up places is a good application of forward geocoding.
#
# Read this blog post for more background:
#
# https://developer.here.com/blog/turn-text-into-here-maps-with-python-nltk

# %% [markdown]
# Example of a travel article without a map:
# - [25 Best Things to Do in Cleveland, OH](https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html)
# - [US News Travel Section](https://travel.usnews.com/Cleveland_OH/Things_To_Do/)

# %%
import bs4
import nltk
import urllib

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.tag import pos_tag

# %%
url = 'https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html'
response = urllib.request.urlopen(url)
html = response.read()
soup = bs4.BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
#
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en-us" http-equiv="content-language"/>
# <title>25 Best Things to Do in Cleveland, Ohio</title>
# <meta content="Explore Cleveland's vibrant parks, museums and attractions on your weekend getaway." name="description">
# <style>
# a,abbr,acronym,address,applet,b,big,blockquote,body,caption,center,cite,code,dd,del,dfn,div,dl,dt,em,fieldset,font,form,h1,h2,h3,h4,h5,h6,html,i,iframe,img,ins,kbd,label,legend,li,object,ol,p,pre,q,s,samp,small,span,strike,strong,sub,sup,table,tbody,td,tfoot,th,thead,tr,tt,u,ul,var{margin:0;padding:0;font-size:100%;vertical-align:baseline;border:0;outline:0;background:0 0}ol,ul{list-style:none}blockquote,q{quotes:none}address,caption,cite,code,dfn,em,strong,th,var{font-style:normal;font-weight:400}html{font-family:'Open Sans',sans-serif;font-size:1.1em;line-height:1.625em}strong{font-weight:600}em{font-style:italic}:focus{outline:0}@font-face{font-family:BebasNeue;src:url(https://vacationidea.com/css/bebasneue-webfont-webfont.eot);src:url(https://vacationidea.com/css/bebasneue-webfont-webfont.eot?#iefix) format('embedded-opentype'),url(https://vacationidea.com/css/bebasneue-webfont-webfont.woff) format('woff'),url(https://vacationidea.com/css/bebasneue-webfont-webfont.ttf) format('truetype'),url(https://vacationidea.com/css/bebasneue-webfont-webfont.svg#_.regular) format('svg')}body{background:#fff}.wrapper{position:relative;margin:0 auto;width:100%;max-width:1260px}#content-wrap{float:left;margin-top:0}#main-content{float:left;width:100%;display:inline;margin:15px 0}#inner-content{float:left;width:74.603%;margin:0 1.5873% 15px 0}.feature-wrap{float:right;width:72.34%}.feature{float:left;position:relative;width:100%;padding-bottom:15px;margin-bottom:15px;border-bottom:1px solid #d1d1d1}.wide-stream{float:left;width:25.532%;margin:0 2.128% 15px 0}.tlp-text{float:right;width:72.34%;padding-top:0;border-top:1px solid #d1d1d1}.sidebar{float:right;width:23.809%;margin:0 0 1em}.about-wrap{float:left;width:100%}.about-feature{float:right;width:72.34%;margin:15px 0 1em;padding-left:20px;border-left:1px solid #d1d1d1}.screen-wrap{float:left;margin-bottom:24px}.screen-thumb{float:left;width:40%}.relatedsearchesAd { margin:0 0 7px 0;}.screen-box{float:right;width:58%}.screen-thumb-right{float:right;width:40%}.screen-box-left{float:left;width:58%}.about-nav{float:left;width:23.809%;margin:15px 0 1em}.about-nav ul li{margin:0 0 15px}.about-nav h2{font-family:BebasNeue,arial,sans-serif;-webkit-font-smoothing:antialiased;font-size:22px;line-height:15px;font-weight:400;text-transform:uppercase;color:#ff4f00;margin-bottom:10px}.about-nav h2 a{color:#ff4f00}.about-nav h2 a:hover{color:#00aaf6;text-decoration:none}.about-feature h2{float:left;width:100%;font-size:20px;line-height:1.125em;letter-spacing:-1px;margin:0 0 16px;text-rendering:optimizeLegibility}.about-feature h3{float:left;width:100%;font-size:18px;font-weight:600;line-height:1.125em;letter-spacing:-1px;margin:0 0 16px;text-rendering:optimizeLegibility;color:#ff4f00}.about-nav p{font-size:13px;line-height:1.625em;margin-bottom:24px}.about-feature p{font-size:14px;line-height:1.625em;margin-bottom:24px}a:link{color:#0020C2;text-decoration: none;}a:visited{color:#0020C2;text-decoration:underline}a:hover{text-decoration:underline;color:#0020C2}img{border:none;text-decoration:none;width:100%;max-width:100%;height:auto}.anchor{display:block;content:" ";height:50px;margin-top:-50px;visibility:hidden}a.navtoplink{float:right;font-weight:600;text-transform:uppercase;width:16px;height:15px;display:block;background:url(../pix/design/sprite.png) -60px -89px no-repeat}a.navtoplink span{float:right;font-size:20px;line-height:14px;font-weight:600;text-transform:uppercase;padding-right:22px;color:#00aaf6}.feature h1 a:hover,.post h3 a:hover,ol.top-five-items li a:hover{text-decoration:none;color:#ff4f00}.tlp-feature-ad{float:left;margin:6px 0 0}.content-ad-right{float:right;margin:10px 0 1.25em .625em}.content-ad-slide{float:left;width:auto;margin:10px 0 1em}.content-ad-slide img {width: auto;}.content-ad-left{float:left;margin:6px .625em .625em 0}.bannerBottom{float:left;margin:0 0 20px}.bannerArticleSidebar{float:left;margin:0 0 1.625em}.bannerArticleSidebar img,.bannerBottom img,.content-ad-left ...
# .example_responsive_1 { width: 320px; height: 100px; }
# @media(min-width: 310px) { .example_responsive_1 { width: 300px; height: 250px; } }
# @media(min-width: 350px) { .example_responsive_1 { width: 336px; height: 280px; } }
# </style>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#    var define300and336sizes = googletag.sizeMapping().
# addSize([992, 0], [[336, 280], [1, 1]]).
# addSize([768, 0], [[336, 280], [1, 1]]).
# addSize([340, 0], [[336, 280], [1, 1]]).
# addSize([320, 0], [[300, 250], [1, 1]]).
# addSize([0, 0], [1, 1]).
# build();
#
# </script>
# <script>
#
#
#   googletag.cmd.push(function() {
#      googletag.defineSlot('/19396384/AdUnit101', [[300, 250], [336, 280]], 'div-gpt-ad-1545928059361-0').addService(googletag.pubads());
#      googletag.defineSlot('/19396384/AdUnit102', [[300, 250], [336, 280]], 'div-gpt-ad-1545949075026-0').addService(googletag.pubads());
#       googletag.defineSlot('/19396384/AdUnit103', [[336, 280], [300, 250]], 'div-gpt-ad-1545949251612-0').addService(googletag.pubads());
#       googletag.defineSlot('/19396384/AdUnit104', [[336, 280], [300, 250]], 'div-gpt-ad-1545949291787-0').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/AdUnit105', [[300, 250], [336, 280]], 'div-gpt-ad-1545949322999-0').addService(googletag.pubads());
# googletag.defineSlot('/19396384/AdUnit106', [[300, 250], [336, 280]], 'div-gpt-ad-1545949357813-0').addService(googletag.pubads());
#  googletag.defineSlot('/19396384/AdUnit107', [[300, 250], [336, 280]], 'div-gpt-ad-1545949390864-0').addService(googletag.pubads());
#   googletag.defineSlot('/19396384/AdUnit108', [[300, 250], [336, 280]], 'div-gpt-ad-1545949421800-0').addService(googletag.pubads());
#   googletag.defineSlot('/19396384/AdUnit109', [[336, 280], [300, 250]], 'div-gpt-ad-1545949451331-0').addService(googletag.pubads());
#   googletag.defineSlot('/19396384/AdUnit110', [[336, 280], [300, 250]], 'div-gpt-ad-1545949479163-0').addService(googletag.pubads());
#   googletag.defineSlot('/19396384/AdUnit111', [[300, 250], [336, 280]], 'div-gpt-ad-1545949510014-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit112', [[300, 250], [336, 280]], 'div-gpt-ad-1545949543861-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit113', [[336, 280], [300, 250]], 'div-gpt-ad-1545949572691-0').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/AdUnit114', [[300, 250], [336, 280]], 'div-gpt-ad-1545949622213-0').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/AdUnit115', [[300, 250], [336, 280]], 'div-gpt-ad-1545949653273-0').addService(googletag.pubads());
# googletag.defineSlot('/19396384/AdUnit116', [[300, 250], [336, 280]], 'div-gpt-ad-1545949681529-0').addService(googletag.pubads());
#
# googletag.defineSlot('/19396384/AdUnit117', [[336, 280], [300, 250]], 'div-gpt-ad-1545949728184-0').addService(googletag.pubads());
#  googletag.defineSlot('/19396384/AdUnit118', [[300, 250], [336, 280]], 'div-gpt-ad-1545949760278-0').addService(googletag.pubads());
#  googletag.defineSlot('/19396384/AdUnit119', [[336, 280], [300, 250]], 'div-gpt-ad-1545949786771-0').addService(googletag.pubads());
#   googletag.defineSlot('/19396384/AdUnit120', [[300, 250], [336, 280]], 'div-gpt-ad-1545949813475-0').addService(googletag.pubads());
#   googletag.defineSlot('/19396384/AdUnit121', [[300, 250], [336, 280]], 'div-gpt-ad-1545949840942-0').addService(googletag.pubads());
#   googletag.defineSlot('/19396384/AdUnit122', [[300, 250], [336, 280]], 'div-gpt-ad-1545949868047-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit123', [[300, 250], [336, 280]], 'div-gpt-ad-1545949896261-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit124', [[300, 250], [336, 280]], 'div-gpt-ad-1545949920169-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit125', [[300, 250], [336, 280]], 'div-gpt-ad-1545949944652-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit126', [[300, 250], [336, 280]], 'div-gpt-ad-1545949973301-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit127', [[300, 250], [336, 280]], 'div-gpt-ad-1545950012194-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit128', [[300, 250], [336, 280]], 'div-gpt-ad-1545950038561-0').addService(googletag.pubads());
#    googletag.defineSlot('/19396384/AdUnit129', [[300, 250], [336, 280]], 'div-gpt-ad-1545950064398-0').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/AdUnit130', [[336, 280], [300, 250]], 'div-gpt-ad-1545950093691-0').addService(googletag.pubads());
#
#     googletag.defineSlot('/19396384/2018RightNav1', [300, 600], 'div-gpt-ad-1514442190128-0').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav10This', [300, 600], 'div-gpt-ad-1514442190128-1').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav11', [300, 600], 'div-gpt-ad-1514442190128-2').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav12', [300, 600], 'div-gpt-ad-1514442190128-3').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav13', [300, 600], 'div-gpt-ad-1514442190128-4').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav14', [300, 600], 'div-gpt-ad-1514442190128-5').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav15', [300, 600], 'div-gpt-ad-1514442190128-6').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav2', [300, 600], 'div-gpt-ad-1514442190128-7').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav3', [300, 600], 'div-gpt-ad-1514442190128-8').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav4', [300, 600], 'div-gpt-ad-1514442190128-9').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav5', [300, 600], 'div-gpt-ad-1514442190128-10').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav6', [300, 600], 'div-gpt-ad-1514442190128-11').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav7', [300, 600], 'div-gpt-ad-1514442190128-12').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav8This', [300, 600], 'div-gpt-ad-1514442190128-13').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018RightNav9This', [300, 600], 'div-gpt-ad-1514442190128-14').addService(googletag.pubads());
#
#     googletag.defineSlot('/19396384/2018Slide10Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-15').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide11Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-16').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide12Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-17').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide13Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-18').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide14Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-19').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide15Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-20').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide16Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-21').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide17Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-22').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide18Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-23').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide19Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-24').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide20Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-25').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide21Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-26').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide22Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-27').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide3Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-28').addService(googletag.pubads());
#
#     googletag.defineSlot('/19396384/2018Slide5Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-29').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide6Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-30').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide7Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-31').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide8Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-32').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/2018Slide9Unit', [[300, 250], [336, 280]], 'div-gpt-ad-1514442190128-33').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/VacationIdea_Article_1_300', [300, 250], 'div-gpt-ad-1514442190128-34').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/VacationIdea_Article_3_300', [300, 250], 'div-gpt-ad-1514442190128-35').addService(googletag.pubads());
#     googletag.defineSlot('/19396384/VacationIdea_Article_LastMN_300', [300, 250], 'div-gpt-ad-1514442190128-36').addService(googletag.pubads());
#     googletag.pubads().collapseEmptyDivs();
#     googletag.enableServices();
#   });
# </script>
# <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css"/>
# <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js"></script>
# <script>
# window.addEventListener("load", function(){
# window.cookieconsent.initialise({
#   "palette": {
#     "popup": {
#       "background": "#edeff5",
#       "text": "#838391"
#     },
#     "button": {
#       "background": "#4b81e8"
#     }
#   },
#   "theme": "edgeless",
#   "content": {
#     "message": "This website uses cookies.",
#     "link": "Review",
#     "href": "https://vacationidea.com/about/privacypolicy.cfm"
#   }
# })});
# </script>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700,600,400italic|Roboto+Slab" rel="stylesheet" type="text/css"/>
# <meta content="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="https://vacationidea.com/pix/img25Hy8R/destinations/best-things-to-do-in-cleveland_t.jpg" property="og:image"/>
# <meta content="25 Best Things to Do in Cleveland, Ohio" property="og:title"/>
# <meta content="Explore Cleveland's vibrant parks, museums and attractions on your weekend getaway." property="og:description"/>
# <meta content="VacationIdea" property="og:site_name"/>
# <meta content="194649640656565" property="fb:app_id"/>
# <link href="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html" rel="canonical">
# <meta content="photo" name="twitter:card"/>
# <meta content="https://vacationidea.com/pix/img25Hy8R/destinations/best-things-to-do-in-cleveland_t.jpg" name="twitter:image"/>
# <meta content="@vacationidea" name="twitter:site"/>
# <meta content="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html" name="twitter:url"/>
# <meta and="" attractions="" content="Explore Cleveland" getaway.'="" museums="" name="twitter:description" on="" parks,="" s="" vibrant="" weekend="" your=""/>
# <meta content="25 Best Things to Do in Cleveland, Ohio" name="twitter:title"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js" type="text/javascript"></script>
# </link></meta></head>
# <body id="page">
# <div id="logoWrap">
# <div class="header">
# <div id="logo">
# <a href="https://vacationidea.com/"><img alt="VacationIdea" img="" src="https://vacationidea.com/pix/design/logo.png"/></a>
# <br/>
# </div>
# <div class="socialSprites">
# <ul>
# <li><a class="facebookNav" href="https://www.facebook.com/vacationidea" target="_blank"></a></li>
# <li><a class="twitterNav" href="https://twitter.com/vacationidea" target="_blank"></a></li>
# </ul>
# </div> <!-- end socialSprites -->
# <div class="search-wrap">
# <div class="search-big">
# <form action="https://vacationidea.com/search/SearchRG-new.cfm" class="form-wrapper cf" id="cse-search-box" method="get"> <input name="cx" type="hidden" value="partner-pub-9262452885249978:qd92jz-oely"/><input name="cof" type="hidden" value="FORID:10"/><input name="ie" type="hidden" value="ISO-8859-1"/><input name="q" placeholder="" type="text" value=""/>
# <button id="search-submit" name="sa" type="submit" value="Search"></button> </form>
# </div>
# </div>
# </div> <!-- end header-->
# <div class="clearFloat"></div> </div><!-- logoWrap-->
# <div id="header-wrap">
# <div class="header-scroll">
# <div class="header"> <div id="logoMobi"><a href="https://vacationidea.com/"><img alt="Vacation Idea" src="https://vacationidea.com/pix/design/logoMobi.png"/></a></div>
# <a href="#nav" id="toggle-nav">Toggle navigation</a>
# <ul class="sf-menu" id="nav">
# <li><a href="https://vacationidea.com/"><span id="home-icon">Home</span></a></li>
# <li class="dropdown"><a href="https://vacationidea.com/beaches.html">Beach Vacations</a></li>
# <li><a href="https://vacationidea.com/romance.html">Romantic Getaways</a></li>
# <li><a href="https://vacationidea.com/family.html">Family</a></li>
# <li class="dropdown"><a href="https://vacationidea.com/Weekend_Getaways.html">Weekend Getaways</a></li>
# <li><a href="https://vacationidea.com/packages/last-minute.html">Last Minute</a></li>
# </ul>
# <div class="search-top">
# <a class="search-top" href="#">Search this site</a>
# <div class="search-top-reveal">
# <form action="https://vacationidea.com/search/SearchRG-new.cfm" id="cse-search-box" method="get"> <input name="cx" type="hidden" value="partner-pub-9262452885249978:qd92jz-oely"/><input name="cof" type="hidden" value="FORID:10"/><input name="ie" type="hidden" value="ISO-8859-1"/><input name="q" placeholder="" type="text" value=""/>
# <button id="search-submit" name="sa" type="submit" value="Search">Search</button> </form>
# </div>
# </div>
# </div> <!-- end h--> <div class="clearFloat"></div>
# </div> <!-- header-scroll-->
# </div> <!-- headerWrap-->
# <div class="wrapper">
# <div id="content-wrap">
# <div id="main-content">
# <div class="clearFloat"></div>
# <div class="article-wide">
# <div class="article-narrow">
# <div class="article">
# <h1>25 Best Things to Do in Cleveland, Ohio</h1>
# <div class="wide-image">
# <img alt="Cleveland at night" src="https://vacationidea.com/pix/img25Hy8R/destinations/best-things-to-do-in-cleveland_t5.jpg"/>
# <div class="credit">© Courtesy of rudi1976/Fotolia.com</div>
# <div class="clearer"></div>
# </div>
# <div class="article-text"><div class="clearFloat"></div>
# <div class="content-ad-right">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- ATF-300-April19 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9262452885249978" data-ad-slot="7657144654" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br> <br/></br></div>
# <p>Cleveland, <a href="https://vacationidea.com/destinations/best-places-to-visit-in-ohio.html" target="_blank">Ohio</a> is a vibrant, culturally diverse city with world-class museums, <a href="https://vacationidea.com/ohio/best-free-things-to-do-in-cleveland.html" target="_blank">free attractions</a>, <a href="https://vacationidea.com/ohio/best-cleveland-wedding-venues.html" target="_blank">unique wedding venues</a> and beautiful <a href="https://vacationidea.com/ohio/best-cleveland-parks.html" target="_blank">parks</a>. Explore the trendy <a href="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html#slide1">University Circle</a> area, visit the <a href="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html#slide6">International Women's Air &amp; Space Museum</a>, the <a href="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html#slide7">Museum of Contemporary Art</a>, and the <a href="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html#slide10">Rock and Roll Hall of Fame Museum</a>.
#
# Best things to do in Cleveland, <a href="https://vacationidea.com/weekend_getaways/best-in-ohio.html" target="_blank">Ohio</a> <a href="https://vacationidea.com/ohio/best-things-to-do-in-cleveland-with-kids.html" target="_blank">with kids</a> include the <a href="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html#slide14">Cleveland Metroparks Zoo</a> and the <a href="https://vacationidea.com/destinations/best-things-to-do-in-cleveland.html#slide5">Greater Cleveland Aquarium</a>.
#
# 	<p>More ideas: <a href="https://vacationidea.com/california/best-beaches-in-california.html" target="_blank">Best California Beaches</a>, <a href="https://vacationidea.com/destinations/best-places-to-visit-in-oregon.html" target="_blank">Oregon</a>, <a href="https://vacationidea.com/weekend_getaways/florida_weekend_getaways.html" target="_blank">Florida Weekend Getaways</a>
# <div class="clearer"></div>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Slide 12 Responsive Sept 2017 -->
# <ins class="adsbygoogle example_responsive_1" data-ad-client="ca-pub-9262452885249978" data-ad-format="auto" data-ad-slot="2316815739" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br/>
# <!-- end wide-image TEST -->
# <div class="slideshow">
# <span class="anchor" id="slide1"></span>
# <h2 class="slide-title"><span style="font-size: 0.8em; padding-top:3px; padding-bottom:5px;">  1.</span>University Circle</h2>
# <div class="slide-caption">
# <div class="slide-image">
# <img alt="University Circle" src="https://vacationidea.com/pix/img25Hy8R/destinations/t-t1_university_circle_5447_mobi.jpg"/> <div class="credit">© Courtesy of Kenneth Sponsler - Fotolia.com</div>
# <div class="clearFloat"></div>
# <div class="content-ad-left">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Slide 2 Highest Responsive -->
# <ins class="adsbygoogle example_responsive_1" data-ad-client="ca-pub-9262452885249978" data-ad-format="auto" data-ad-slot="3447486734" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br/> <div class="clearFloat"></div>
# </div>
# </div>
# <p>
#
# 	 University Circle, a famous urban district covering a square mile, is home to some of Cleveland’s top education, health care, arts, cultural, religious, and social service institutions. Situated near downtown Cleveland, the area is located on Euclid Avenue and is known for its vibrant, bustling energy. You’ll enjoy spending time among the many retailers, restaurants, bars, and residences. <p>Take in some history with a stroll along the quaint side streets of Magnolia, Ford, Bellflower, and Juniper where beautifully preserved 19th-century mansions have been transformed into hip hotels and trendy coffee shops. Alternatively, you can take a short ride along the Euclid Corridor to the modern arts and cultural district at Euclid and Mayfield. If you are wondering what to do in Cleveland this weekend, Wade Oval plays host to several outdoor events, live concerts, and movie nights during the summer while The Rink at Wade Oval is ideal for ice-skating during the winter months.
#
#
#
#
#    </p>
# <p>More quick trip ideas: <a href="https://vacationidea.com/weekend_getaways/california-weekend.html" target="_blank">Weekend Getaways in California</a>, <a href="https://vacationidea.com/family/best-family-beach-vacations-east-coast.html" target="_blank">Best East Coast beaches</a>, <a href="https://vacationidea.com/weekend_getaways/best-in-south-carolina.html" target="_blank">SC</a>, <a href="https://vacationidea.com/destinations/best-things-to-do-in-texas.html" target="_blank">TX</a>, <a href="https://vacationidea.com/north-carolina/best-north-carolina-day-trips.html" target="_blank">NC</a>, <a href="https://vacationidea.com/weekend_getaways/romantic_weekends.html" target="_blank">Romantic weekend getaways</a>
# <div class="clearFloat"></div>
# <div class="content-ad-left">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- chfolder2019-u2-2nd-ohio-vacation -->
# <ins class="adsbygoogle example_responsive_1" data-ad-client="ca-pub-9262452885249978" data-ad-format="auto" data-ad-slot="6805800900" data-full-width-responsive="true" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br/> <div class="clearFloat"></div>
# </div>
# </p></p></div> <!-- slideContent -->
# </div> <!-- slideBox -->
# <div class="clearFloat"></div> <div class="slideshow">
# <span class="anchor" id="slide2"></span>
# <h2 class="slide-title"><span style="font-size: 0.8em; padding-top:3px; padding-bottom:5px;">   2. </span>Cleveland Museum of Art   </h2>
# <div class="slide-caption">
# <div class="slide-image"> <img alt="Cleveland Museum of Art" src="https://vacationidea.com/pix/img25Hy8R/destinations/t-t2_cleveland_museum_of_art_5447_mobi.jpg"/> <div class="credit">© Courtesy of Jennifer Elizabeth - Fotolia.com</div>
# <div class="content-ad-left">
# <!-- /19396384/AdUnit104 -->
# <div id="div-gpt-ad-1545949291787-0">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1545949291787-0'); });
# </script>
# </div>
# <br> <br/></br></div>
# <div class="clearFloat"></div>
# </div>
# <p>
#
# 	 Founded in 1913 “for the benefit of all the people forever,” the <a href="https://vacationidea.com/attractions/the-cleveland-museum-of-art.html" target="_blank">Cleveland Museum of Art</a> is one of the country’s most distinguished cultural institutions and one of the top Cleveland attractions. Housed in a beautifully preserved neoclassic building of white Georgian marble, the museum lies at the center of the city’s Fine Arts Garden, just north of the Wade Lagoon. <p>The museum has a fantastic collection of more than 30,000 works of art that span over 5,000 years; some of the collections boast works from ancient Egypt, as well as world-renowned masterpieces from Europe, Asia, and Africa. In keeping with its mission of bringing art to the people of Cleveland, Ohio the museum also fills its calendar with special exhibitions, lectures, films, and musical programs for the public, as well as community-based programs and performing arts series.
#
# <p><i>11150 East Boulevard, Cleveland, OH Phone: 216-421-7340</i>
# </p>
# <p>Things to do near me: <a href="https://vacationidea.com/getaways/weekend_getaways_from_seattle.html" target="_blank">Weekend Getaways from Seattle</a>, <a href="https://vacationidea.com/north-carolina/best-north-carolina-day-trips.html" target="_blank">NC day trips</a>, <a href="https://vacationidea.com/florida/best-family-beach-vacations-in-florida.html" target="_blank">FL</a>, <a href="https://vacationidea.com/getaways/best-day-trips-from-phoenix.html" target="_blank">From Phoenix</a>, <a href="https://vacationidea.com/weekend_getaways/best-in-west-virginia.html" target="_blank">WV</a>, <a href="https://vacationidea.com/weekend_getaways/best-in-indiana.html" target="_blank">IN</a>, <a href="https://vacationidea.com/ideas/best-day-trips-from-atlanta.html" target="_blank">Near Atlanta</a>, <a href="https://vacationidea.com/weekend_getaways/best-in-alabama.html" target="_blank">AL</a>
# <div class="clearFloat"></div>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 2nd-Feb2019 -->
# <ins class="adsbygoogle example_responsive_1" data-ad-client="ca-pub-9262452885249978" data-ad-format="auto" data-ad-slot="3215077667" data-full-width-responsive="true" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br/> <div class="clearFloat"></div>
# </p></p></p></div> <!-- slideContent -->
# </div> <!-- slideBox -->
# <div class="clearFloat"></div> <div class="slideshow">
# <span class="anchor" id="slide3"></span>
# <h2 class="slide-title"><span style="font-size: 0.8em; padding-top:3px; padding-bottom:5px;">  3.</span>What to do in Cleveland: West Side Market</h2>
# <div class="slide-caption">
# <div class="slide-image">
# <img alt="What to do in Cleveland: West Side Market" src="https://vacationidea.com/pix/img25Hy8R/destinations/t-t3_what_to_do_in_cleveland_west_s_5447_mobi.jpg"/> <div class="credit">© Courtesy of Henryk Sadura - Fotolia.com</div>
# <div class="clearFloat"></div>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- ch2019-u1-things-to-do -->
# <ins class="adsbygoogle example_responsive_1" data-ad-client="ca-pub-9262452885249978" data-ad-format="auto" data-ad-slot="9379282916" data-full-width-responsive="true" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br> <div class="clearFloat"></div>
# </br></div>
# <p>
#
# 	 The <a href="https://vacationidea.com/ohio/things-to-do-in-cleveland-west-side-market.html" target="_blank">West Side Market</a> is Cleveland’s oldest public market where over 100 producers, artisans, and vendors sell their wares. Market stalls brim with charcuterie and meats, succulent seafood, freshly picked fruits and vegetables, dairy products, fresh flowers, spices and nuts. <p>Bakers sell homemade baked bread, pastries, and other baked goods while artisan chefs and cooks offer delicious ready-to-eat meals. Built in 1912 to replace the original Pearl Street Market, the West Side Market is the last remaining market of three that were constructed to serve Cleveland’s growing immigrant population in the early 20th century. Today, the market continues to offer an authentic and culturally diverse shopping experience to locals and visitors alike. The West Side Market is one of the best things to do in Cleveland, Ohio for foodies.
#
a href="https://vacationidea.com/getaways/best-romantic-weekend-getaways-in-connecticut.html" target="_blank">CT</a>, <a href="https://vacationidea.com/weekend_getaways/beautiful-romantic-getaways-in-illinois.html" target="_blank">IL</a>, <a href="https://vacationidea.com/weekend_getaways/romantic-northern-california.html" target="_blank">CA</a>, <a href="https://vacationidea.com/weekend_getaways/best-in-maryland.html" target="_blank">MD</a>
# <div class="content-ad-left">
# <!-- /19396384/2018Slide13Unit -->
# <div id="div-gpt-ad-1514442190128-18" style="height:250px; width:300px;">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1514442190128-18'); });
# </script>
# </div>
# <br/> </div>
# <div class="clearFloat"></div>
# </p></p></p></div> <!-- slideContent -->
# </div> <!-- slideBox -->
# <div class="clearFloat"></div> <div class="slideshow">
# <span class="anchor" id="slide7"></span>
# <h2 class="slide-title"><span style="font-size: 0.8em; padding-top:3px; padding-bottom:5px;">   7. </span>Museum of Contemporary Art (MOCA)   </h2>
# <div class="slide-caption">
# <div class="slide-image"> <img alt="Museum of Contemporary Art (MOCA)" src="https://vacationidea.com/pix/img25Hy8R/destinations/t-t7_museum_of_contemporary_art_(mo_5447_mobi.jpg"/> <div class="credit">© Museum of Contemporary Art</div> <div class="clearFloat"></div>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Slide 7 Responsive Sept 2017 -->
# <ins class="adsbygoogle example_responsive_1" data-ad-client="ca-pub-9262452885249978" data-ad-format="auto" data-ad-slot="3394217396" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br><div class="clearFloat"></div>
# </br></div>
# <p>
#
# 		Cleveland’s <a href="https://vacationidea.com/attractions/museum-of-contemporary-art.html" target="_blank">Museum of Contemporary Art</a> (MOCA) is the region’s only contemporary art museum dedicated to showcasing modern and contemporary art through a range of new-age, evolving exhibitions. Founded in 1968, this non-profit institution has been playing a vital role in Cleveland’s cultural landscape for over 45 years. <p>The museum proudly presents the works of more than 2,000 artists through permanent and traveling exhibitions, as well as artists’ first solo shows. Aiming to challenge, inspire, and teach a broad range of audiences about modern art, the museum creates a unique and dynamic space in which to fuel imagination and cultivate creativity. The Museum of Contemporary Art is one of the best things to do in Cleveland for art lovers. It also offers a variety of programs and open-ended activities that encourage collaboration and interaction.
#
# <p><i>11400 Euclid Avenue, Cleveland, Ohio</i>
# </p>
# ...
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1514442190128-34'); });
# </script>
# </div>
# <br/></div><div class="clearFloat"></div>
# </p></p></p></div> <!-- slideContent -->
# </div> <!-- slideBox -->
# <div class="clearFloat"></div> <div class="slideshow">
# <span class="anchor" id="slide25"></span>
# <h2 class="slide-title"><span style="font-size: 0.8em; padding-top:3px; padding-bottom:5px;">  25.</span>Fun places to go near me: Cleveland Metroparks Zoo</h2>
# <div class="slide-caption">
# <div class="slide-image">
# <img alt="Fun places to go near me: Cleveland Metroparks Zoo" src="https://vacationidea.com/pix/img25Hy8R/destinations/best-things-to-do-in-cleveland_g25_mobi.jpg"/> <div class="credit">© Courtesy of Timothy - Fotolia.com</div>
# <div class="content-ad-left">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 300-April19-25th -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9262452885249978" data-ad-slot="6384070362" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script><br/><br/>
# </div>
# <div class="clearFloat"></div>
# </div>
# <p>
#
# 	 Founded in 1892, the <a href="https://vacationidea.com/attractions/cleveland-metroparks-zoo.html" target="_blank">Cleveland Metroparks Zoo</a> is home to several bio-thematic areas that house animals from different regions of the world and is one of Ohio’s most popular attractions. Spanning 183 acres (74 ha), the zoo is divided into sections that are themed according to the area they represent. Some of the sections are the African Savannah, Northern Trek, Australian Adventure, and the Rainforest. <p>The Cat &amp; Aquatics Building houses one of the largest collections of primate species in North America, and gorillas, lemurs, monkeys and aye-ayes call this building home. Meanwhile, the Wolf Wilderness introduces visitors to life in a northern temperate forest. Visitors can explore the zoo on foot or by riding one of two zoo trams, which follow selected routes around the park.
# <div class="clearFloat"></div>
# <div class="signup">
# <div class="signup-wrap">
# <div class="signup-box">
# <h2 id="newsletterweekend">Like What You've Read?</h2>
# <h3>Get Best Ideas in Your Inbox</h3>
# <form action="https://organiczoom.us1.list-manage.com/subscribe/post" id="signup1" method="post">
# <input id="email1" maxlength="50" name="MERGE0" placeholder="Email" size="25" type="text"/>
# <input name="u" type="hidden" value="ceda50755a5598b14693f92d1"/><input name="id" type="hidden" value="bc284d8d5f"/><input name="EMAILTYPE" type="hidden" value="html"/>   <button type="submit">Done!</button>
# </form>
# </div>
# </div> <!-- signup wrap-->
# </div> <!-- signup -->
# <p><br/>
# <p>
# <br/><br/> </p>
# <div class="clearFloat"></div>
# <div class="clearFloat"></div>
# <div class="related-links">
# <h2 class="column-heading">More Features</h2>
# <div class="post-left">
# <div class="post">
# <a class="link-wrap" href="https://vacationidea.com/ohio/best-things-to-do-in-canton.html">
# <div class="postPic"> <img alt="15 Best Things to Do in Canton  " height="178" src="https://vacationidea.com/pix/img25Hy8R/articles/best-things-to-do-in-canton_t.jpg"> </img></div>
# <h3>15 Best Things to Do in Canton, Ohio</h3></a>
# </div>
# </div> <!-- post-left -->
# <div class="post-left">
# <div class="post">
# <a class="link-wrap" href="https://vacationidea.com/ohio/best-columbus-parks.html">
# <div class="postPic"> <img alt="25 Columbus Parks You Won’t Want to Miss" height="178" src="https://vacationidea.com/pix/img25Hy8R/articles/columbus-parks-you-wont-want-to-miss_t.jpg"> </img></div>
# <h3>25 Best Columbus Parks</h3></a>
# </div>
# </div> <!-- post-left -->
# <div class="post-right">
# <div class="post">
# <a class="link-wrap" href="https://vacationidea.com/ohio/best-lakes-in-ohio.html">
# <div class="postPic"> <img alt="25 Best Ohio Lakes" height="178" src="https://vacationidea.com/pix/img25Hy8R/articles/best-ohio-lakes_t.jpg"> </img></div>
# <h3>25 Best Lakes and Beaches in Ohio</h3></a>
# </div>
# </div> <!-- post-left -->
# <div class="clearFloat"></div>
# </div>
# <div class="clearFloat"></div>
# </p></div> <!-- end article-narrow -->
# <div class="wide-stream">
# <h2 class="column-heading">VacationIdea.com</h2>
# <div class="post-wrap">
# <div class="post-left">
# <div class="post">
# <a class="link-wrap" href="https://vacationidea.com/destinations/best-places-to-visit-in-ohio.html" target="_blank">
# <div class="postPic">
# <img alt="Cleveland" height="178" src="https://vacationidea.com/pix/img25Hy8R/destinations/best-places-to-visit-in-ohio_t.jpg"/></div>
# <h3>25 Best Places to Visit in Ohio</h3></a>
# </div>
# </div> <!-- post-left or right -->
# <div class="post-right">
# <div class="post">
# </div>
# </div> <!-- post-right -->
# </div> <!-- post-wrap -->
# <div class="post-wrap">
# <div class="post-left">
# <div class="post">
# <a class="link-wrap" href="https://vacationidea.com/ohio/flea-markets-ohio.html" target="_blank">
# <div class="postPic">
# <img alt="23 Best Ohio Flea Markets" height="178" src="https://vacationidea.com/pix/img25Hy8R/articles/best-ohio-flea-markets_t.jpg"/></div>
# <h3>23 Best Flea Markets in Ohio</h3></a>
# </div>
# </div> <!-- post-left or right -->
# </div> <!-- sidebar-widget--><br>
# <div class="clearFloat"></div>
# <br> <br>
# </br></br></br></br></br></br></div> <!-- end sidebar -->
# <div class="clearFloat"></div>
# <a class="navtoplink" href="#page"><span>Top</span></a>
# </div> <!-- end mainContent -->
# <div class="clearFloat"></div>
# </div> <!-- end contentWrap -->
# </div> <!-- end wrapper -->
# <div id="footerWrap"><div class="wrapper"><div id="footer">
# <div id="logo-footer">
# <img alt="VacationIdea" src="https://vacationidea.com/pix/design/logoMobi.png">
# </img></div>
# <div class="fcolumn">
# <ul>
# <li><a href="https://vacationidea.com/about/aboutus.cfm">About Us/Contact Us</a></li>
# <li>/</li>
# <li><a href="https://vacationidea.com/about/privacypolicy.cfm">Privacy Policy</a></li>
# <li>/</li>
# <li><a href="https://vacationidea.com/about/useragreement.cfm">Terms of Service</a></li>
# </ul>
# </div>
# <div class="clearer"></div>
# <span class="copyright"><br>Disclaimer: All information provided should be independently verified. Before going on your trip, be sure to consult with your travel agent.
#
#   <br>Copyright © 2019 VacationIdea, LLC All Rights Reserved.
#
#
#
# </br></br></span>
# </div> <!-- footer -->
# </div> <!-- wrapper-->
# </div> <!-- footerWrap -->
# <script type="text/javascript">
# function downloadJSAtOnload() {
# var element = document.createElement("script");
# element.src = "https://vacationidea.com/scripts/vacationidea.js";
# document.body.appendChild(element);
# }
# if (window.addEventListener)
# window.addEventListener("load", downloadJSAtOnload, false);
# else if (window.attachEvent)
# window.attachEvent("onload", downloadJSAtOnload);
# else window.onload = downloadJSAtOnload;
# </script>
# <script type="text/javascript">
# function downloadJSAtOnload() {
# var element = document.createElement("script");
# element.src = "https://www.google.com/cse/brand?form=cse-search-box&amp;lang=en";
# document.body.appendChild(element);
# }
# if (window.addEventListener)
# window.addEventListener("load", downloadJSAtOnload, false);
# else if (window.attachEvent)
# window.attachEvent("onload", downloadJSAtOnload);
# else window.onload = downloadJSAtOnload;
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-332538-1', 'auto');
#   ga('require', 'displayfeatures');
#   ga('send', 'pageview');
# </script>
# </body>
# </html>

# %%
for section in soup(['script', 'style']):
    section.decompose()
    
text = soup.get_text()
text
# Out:
# "\n\n\n\n\n25 Best Things to Do in Cleveland, Ohio\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n \n \n\n\n \n \n\n\n \nToggle navigation\n\nHome\nBeach Vacations\nRomantic Getaways\nFamily\nWeekend Getaways\nLast Minute\n\n\nSearch this site\n\n \nSearch \n\n\n  \n \n \n\n\n\n\n\n\n\n25 Best Things to Do in Cleveland, Ohio\n\n\n© Courtesy of rudi1976/Fotolia.com\n\n\n\n\n\n\n\n\n \nCleveland, Ohio is a vibrant, culturally diverse city with world-class museums, free attractions, unique wedding venues and beautiful parks. Explore the trendy University Circle area, visit the International Women's Air & Space Museum, the Museum of Contemporary Art, and the Rock and Roll Hall of Fame Museum. \r\n\r\nBest things to do in Cleveland, Ohio with kids include the Cleveland Metroparks Zoo and the Greater Cleveland Aquarium. \r\n\r\n\tMore ideas: Best California Beaches, Oregon, Florida Weekend Getaways\n\n\n\n\n\n\n\n\n\n  1.University Circle\n\n\n © Courtesy of Kenneth Sponsler - Fotolia.com\n\n\n\n\n\n\n \n\n\n \r\n\r\n\t University Circle, a famous urban district covering a square mile, is home to some of Cleveland’s top education, health care, arts, cultural, religious, and social service institutions. Situated near downtown Cleveland, the area is located on Euclid Avenue and is known for its vibrant, bustling energy. You’ll enjoy spending time among the many retailers, restaurants, bars, and residences. Take in some history with a stroll along the quaint side streets of Magnolia, Ford, Bellflower, and Juniper where beautifully preserved 19th-century mansions have been transformed into hip hotels and trendy coffee shops. Alternatively, you can take a short ride along the Euclid Corridor to the modern arts and cultural district at Euclid and Mayfield. If you are wondering what to do in Cleveland this weekend, Wade Oval plays host to several outdoor events, live concerts, and movie nights during the summer while The Rink at Wade Oval is ideal for ice-skating during the winter months.  \r\n\r\n \r\n\t\r\n\r\n   \nMore quick trip ideas: Weekend Getaways in California, Best East Coast beaches, SC, TX, NC, Romantic weekend getaways\n\n\n\n\n\n\n \n\n \n \n \n\n   2. Cleveland Museum of Art   \n\n  © Courtesy of Jennifer Elizabeth - Fotolia.com\n\n\n\n\n\n \n\n\n \r\n\r\n\t Founded in 1913 “for the benefit of all the people forever,” the Cleveland Museum of Art is one of the country’s most distinguished cultural institutions and one of the top Cleveland attractions. Housed in a beautifully preserved neoclassic building of white Georgian marble, the museum lies at the center of the city’s Fine Arts Garden, just north of the Wade Lagoon. The museum has a fantastic collection of more than 30,000 works of art that span over 5,000 years; some of the collections boast works from ancient Egypt, as well as world-renowned masterpieces from Europe, Asia, and Africa. In keeping with its mission of bringing art to the people of Cleveland, Ohio the museum also fills its calendar with special exhibitions, lectures, films, and musical programs for the public, as well as community-based programs and performing arts series.  \r\n\r\n11150 East Boulevard, Cleveland, OH Phone: 216-421-7340\n\nThings to do near me: Weekend Getaways from Seattle, NC day trips, FL, From Phoenix, WV, IN, Near Atlanta, AL\n\n\n\n\n\n \n \n \n \n\n  3.What to do in Cleveland: West Side Market\n\n\n © Courtesy of Henryk Sadura - Fotolia.com\n\n\n\n\n\n \n\n \r\n\r\n\t The West Side Market is Cleveland’s oldest public market where over 100 producers, artisans, and vendors sell their wares. Market stalls brim with charcuterie and meats, succulent seafood, freshly picked fruits and vegetables, dairy products, fresh flowers, spices and nuts. Bakers sell homemade baked bread, pastries, and other baked goods while artisan chefs and cooks offer delicious ready-to-eat meals. Built in 1912 to replace the original Pearl Street Market, the West Side Market ...

# %%
# Ignore punctuation, duplicates
tokenizer = RegexpTokenizer(r'\w+')
tokens = set(tokenizer.tokenize(text))
tokens
# Out:
# {'open',
#  'insight',
#  'oldest',
#  'crystal',
#  'Lakefront',
#  'other',
#  'stimulate',
#  'panoramic',
#  'beers',
#  'development',
#  'In',
#  'School',
#  'explored',
#  'Peace',
#  'Boulevard',
#  'Circle',
#  'pm',
#  'Berkeley',
#  'colonies',
#  'CIA',
#  'shishito',
#  'heroes',
#  'Zoo',
#  'garden',
#  'Möst',
#  'Franz',
#  'handcrafted',
#  'verified',
#  'll',
#  '88th',
#  'paleontology',
#  'day',
#  'new',
#  'help',
#  'recreation',
#  'Vermont',
#  'bread',
#  'Book',
#  'quick',
#  'Stories',
#  'famous',
#  'numerous',
#  'alfresco',
#  'smoothies',
#  '7340',
#  'UT',
#  'boast',
#  'things',
#  'Meanwhile',
#  'Trips',
#  'gorillas',
#  'all',
#  'get',
#  'Charlottesville',
#  'made',
#  'times',
#  'has',
#  'Marsh',
#  'shimmers',
#  'oven',
#  '74',
#  'tequila',
#  'city',
#  'Tybee',
#  'Programs',
#  '216',
#  'women',
#  'PA',
#  '70',
#  'Boasting',
#  'still',
#  'out',
#  'Hills',
#  '750',
#  'seek',
#  'Maine',
#  'lighting',
#  'exotic',
#  'hour',
#  'spot',
#  'routes',
#  'Coral',
#  'Tampa',
#  'study',
#  'residences',
#  'provides',
#  'your',
#  '661',
#  'Monterey',
#  'TWA',
#  'entertain',
#  'visitors',
#  'hiking',
#  'incredibly',
#  'sell',
#  'James',
#  'Committed',
#  'marine',
#  'fabulous',
#  '1979',
#  'imagination',
#  'Italy',
#  'view',
#  'Space',
#  'Erieside',
#  'stained',
#  '24',
#  'Sunset',
#  '231',
#  'nuts',
#  'Polish',
#  'age',
#  'rustic',
#  'foot',
#  'cocktails',
#  'party',
#  'northern',
#  '1983',
#  'peace',
#  'Vacations',
#  'Sanctuary',
#  'Euclid',
#  'deeper',
#  'profit',
#  'styles',
#  'navigation',
#  'among',
#  'during',
#  'shrirampatki',
#  'impressive',
#  'skating',
#  '21',
#  'provided',
#  'floor',
#  'events',
#  'center',
#  'around',
#  'creates',
#  'future',
#  'site',
#  'Pair',
#  'Caribbean',
#  'Enjoy',
#  'culturally',
#  'landscape',
#  'built',
#  'major',
#  'natural',
#  '175',
#  'dining',
#  'library',
#  'Orchestra',
#  'Ninety',
#  'information',
#  'Wander',
#  'influence',
#  'Festival',
#  'beaches',
#  'Road',
#  'ongoing',
#  'romantic',
#  'Vienna',
#  'World',
#  'inspiring',
#  'opened',
#  'vacation',
#  'Markets',
#  'near',
#  'Visit',
#  'freshly',
#  'fruits',
#  'bar',
#  '18',
#  'guided',
#  'acrylic',
#  'Sandusky',
#  'LLC',
#  'Cool',
#  'year',
#  'due',
#  'overlooking',
#  'find',
#  'mahogany',
#  'All',
#  'turn',
#  'E',
#  '11610',
#  'residents',
#  'which',
#  'tucked',
#  'enjoy',
#  'Canalway',
#  'States',
#  'Raton',
#  'rich',
#  'keeping',
#  'fine',
#  'houses',
#  'eat',
#  'castles',
#  'Canal',
#  'American',
#  'Aiming',
#  'Established',
#  'when',
#  'approximately',
#  'years',
#  've',
#  'name',
#  'dugouts',
#  'later',
#  'boxty',
#  'of',
#  'become',
#  'mastodon',
#  '8803',
#  'newly',
#  '11001',
#  'inviting',
#  'Park',
#  'Mills',
#  'residence',
#  'than',
#  'Guided',
#  'views',
#  'devoted',
#  'stands',
#  'coal',
#  'CA',
#  'panels',
#  '1892',
#  '1',
#  'collaboration',
#  'Photo',
#  'Greater',
#  'internships',
#  'cocktail',
#  'Kenneth',
#  'Major',
#  'Sand',
#  'IWASM',
#  'Vacation',
#  'Spanning',
#  'no',
#  'Building',
#  'piece',
#  'over',
#  'private',
#  'Severance',
#  'scene',
#  '1920s',
#  'beautiful',
#  'crafts',
#  'exhibits',
#  'come',
#  'variety',
#  'Carlsbad',
#  'them',
#  'rudi1976',
#  'collaborations',
#  'on',
#  'cemetery',
#  'Western',
#  '6500',
#  'features',
#  'research',
#  'a',
#  'margarita',
#  'sourced',
#  'parks',
#  '4600',
#  'William',
#  'brings',
#  'located',
#  'date',
#  'museums',
#  'began',
#  'restaurant',
#  'chance',
#  'Sadura',
#  'Voted',
#  'immigrant',
#  'seared',
#  'Detroit',
#  'pancake',
#  'horseback',
#  'Pearl',
#  'Aquarium',
#  'A',
#  'glass',
#  'USA',
#  'Avenue',
#  'interact',
#  'million',
#  'seven',
#  'independently',
#  'Chicago',
#  'Places',
#  'GA',
#  'dedicated',
#  'youth',
#  'produces',
#  'patrons',
#  'IL',
#  'Lauderdale',
#  'skeletons',
#  'West',
#  'café',
#  'light',
#  'Jennifer',
#  'Erie',
#  'ornate',
#  'Wildlife',
#  'provide',
#  'Cleveland',
#  'fans',
#  'Sanibel',
#  'space',
#  'Scottsdale',
#  'Roll',
#  'Search',
#  'they',
#  'acres',
#  'Miami',
#  '1501',
#  'build',
#  'every',
#  'Designed',
#  'DE',
#  'Square',
#  'Field',
#  'Golf',
#  'urban',
#  'scholars',
#  'such',
#  'designated',
#  'Manakiki',
#  'kale',
#  '1968',
#  '22',
#  'popular',
#  'NH',
#  'places',
#  'side',
#  'fan',
#  'at',
#  'Northeast',
#  'Healdsburg',
#  'proudly',
#  's',
#  'Egypt',
#  'Rights',
#  'tournaments',
#  'W',
#  'free',
#  'inspire',
#  'festivals',
#  'inspired',
#  '25',
#  'Welser',
#  'Shaped',
#  'Pacific',
#  'spread',
#  'fantastic',
#  'only',
#  'Room',
#  'Beaches',
#  'locals',
#  'Marble',
#  'getaways',
#  'digital',
#  '1913',
#  'Course',
#  'Virginia',
#  'degrees',
#  'Ford',
#  'away',
#  'theater',
#  'themed',
#  'OH',
#  'entertainment',
#  'vegetables',
#  'If',
#  'interactive',
#  'Airport',
#  'honors',
#  'Pink',
#  'GE',
#  'Arts',
#  'United',
#  'comfortable',
#  'NC',
#  'Rainforest',
#  'flagship',
#  'presenting',
#  'workshops',
#  'Before',
#  'Explore',
#  'Stroll',
#  'Steamship',
#  'upheld',
#  'available',
#  'pays',
#  'kids',
#  'Kayaking',
#  'Ideas',
#  'ice',
#  'second',
#  'creativity',
#  'ensure',
#  'Hiking',
#  'brews',
#  'wafting',
#  'baby',
#  'threats',
#  'that',
#  'slice',
#  'SC',
#  'bachelor',
#  'Ave',
#  'Best',
#  'collected',
#  'NM',
#  'pabrady63',
#  'Gardens',
#  'to',
#  'attractions',
#  'market',
#  'goods',
#  'cafés',
#  'AICAD',
#  'seafood',
#  'influenced',
#  'class',
#  'Taos',
#  'joy',
#  'Us',
#  'where',
#  'Drive',
#  'sled',
#  'its',
#  '623',
#  'Contemporary',
#  'District',
#  'fixtures',
#  'going',
#  'Lake',
#  'days',
#  'Important',
#  'ceiling',
#  'tops',
#  'industries',
#  'Timothy',
#  'kitchen',
#  'delights',
#  'resting',
#  'forever',
#  'step',
#  'Armenian',
#  'gardens',
#  'Restaurants',
#  'Don',
#  'go',
#  'Helen',
#  'bulk',
#  'draft',
#  'fills',
#  'lovely',
#  'Point',
#  'ideal',
#  'Ohio',
#  'four',
#  'Toggle',
#  'into',
#  'while',
#  'multiple',
#  'VA',
#  'educational',
#  'minutes',
#  'monthly',
#  'State',
#  'micro',
#  'stone',
#  'storybook',
#  'house',
#  'are',
#  'musical',
#  'Wilmington',
#  'Mobility',
#  'his',
#  'benefit',
#  'music',
#  'Your',
#  '223',
#  'tasty',
#  'Suite',
#  'ball',
#  'just',
#  'local',
#  'Today',
#  'institutions',
#  'healthy',
#  'receive',
#  'booths',
#  'recreational',
#  'gallon',
#  'under',
#  'span',
#  'architectural',
#  'New',
#  'primate',
#  'foodies',
#  'patio',
#  'Contact',
#  'Rated',
#  'JoMo',
#  'Coastal',
#  'watching',
#  'Resorts',
#  'off',
#  '298',
#  'artistic',
#  'wooden',
#  'myriad',
#  'Fame',
#  'hill',
#  'building',
#  'packed',
#  'restored',
#  'Rink',
#  'tours',
#  'offers',
#  'Chagrin',
#  'Tours',
#  'Hawaii',
#  'locally',
#  'once',
#  'outdoor',
#  'perform',
#  'experiences',
#  'Ft',
#  'Kids',
#  'MD',
#  'displays',
#  'St',
#  'Denver',
#  'Wade',
#  'seasonal',
#  '694',
#  'Waterfalls',
#  'you',
#  'California',
#  'wares',
#  'Diego',
#  'form',
#  'T',
#  'Warm',
#  'WI',
#  'CO',
#  'International',
#  'charcuterie',
#  'goat',
#  'ideas',
#  'understanding',
#  'LA',
#  'contemporary',
#  'economic',
#  'KY',
#  'Shannon',
#  'behind',
#  'Fulton',
#  'several',
#  'milkshakes',
#  'docent',
#  '2',
#  'winter',
#  'best',
#  '9th',
#  '45',
#  'bocce',
#  'ship',
#  'my',
#  'Air',
#  '800',
#  'initiatives',
#  '11',
#  'successes',
#  'room',
#  'including',
#  'ID',
#  'Atlanta',
#  'performers',
#  'Francisco',
#  'detail',
#  'Reservation',
#  'feature',
#  'menu',
#  'travel',
#  'mills',
#  'quality',
#  'pilot',
#  'exhibition',
#  'growing',
#  'institution',
#  'rock',
#  'Monument',
#  'Wolf',
#  'take',
#  'arts',
#  'series',
#  'treats',
#  'wines',
#  'riding',
#  'Hilton',
#  'authentic',
#  'lineup',
#  '23',
#  'hats',
#  'alternates',
#  'Studio',
#  'summer',
#  'retailers',
#  'freight',
#  'walk',
#  'Carrabelli',
#  'institute',
#  'Key',
#  'botany',
#  'had',
#  'National',
#  'Play',
#  'Girls',
#  'an',
#  'century',
#  'state',
#  'Outlet',
#  'FL',
#  'AL',
#  'thirteen',
#  'museum',
#  'ore',
#  'Keller',
#  'Minute',
#  'mammoth',
#  '3900',
#  'like',
#  'park',
#  '20th',
#  'tall',
#  'specimens',
#  'bird',
#  'backdrop',
#  'sharing',
#  'Baseball',
#  'Parkway',
#  'Legends',
#  'family',
#  'vacations',
#  'Casper',
#  'films',
#  'vibrant',
#  'host',
#  'Berea',
#  '601',
#  'Songs',
#  'stroll',
#  'historic',
#  'according',
#  'dog',
#  'Copyright',
#  'small',
#  'KS',
#  'based',
#  'Chandelier',
#  'Progressive',
#  'promises',
#  'magnificent',
#  '44106',
#  'Byzantine',
#  'up',
#  'program',
#  'led',
#  'short',
#  'caves',
#  'Located',
#  'You',
#  'Victorian',
#  'Woodstock',
#  'Their',
#  'meats',
#  'Anaheim',
#  'Inbox',
#  'mile',
#  'country',
#  'service',
#  'sections',
#  'water',
#  '1111',
#  '2401',
#  'Philadelphia',
#  'artists',
#  'covering',
#  'taco',
#  'this',
#  'towns',
#  'acre',
#  'preserved',
#  'whole',
#  'Indians',
#  'number',
#  'greatest',
#  'Gianfranco',
#  'cultivate',
#  'touring',
#  'Fotolia',
#  'Historic',
#  '2019',
#  '1275',
#  'lemurs',
#  'serves',
#  'engagement',
#  'offer',
#  'concerts',
#  'college',
#  'MN',
#  'wine',
#  'from',
#  'Things',
#  'wide',
#  'Assumption',
#  'birding',
#  'bio',
#  'Service',
#  'piping',
#  'orchestra',
#  'Last',
#  '19th',
#  'furtseff',
#  'Tomasz',
#  'holds',
#  'OR',
#  'Residency',
#  'regions',
#  'beer',
#  '2095',
#  'it',
#  'G',
#  '14',
#  'Trek',
#  'ha',
#  'challenge',
#  'Magnolia',
#  'premiere',
#  'Wedding',
#  'Constructed',
#  'NJ',
#  'evening',
#  'hopes',
#  'advantage',
#  'evolving',
#  'Boston',
#  'Randy',
#  'London',
#  'ayes',
#  'give',
#  'power',
#  'voyages',
#  'Cemetery',
#  'early',
#  'premier',
#  'archeology',
#  'Campground',
#  'performing',
#  'AZ',
#  'mushrooms',
#  'Situated',
#  'beloved',
#  'Story',
#  'Zajda',
#  'as',
#  'related',
#  'potato',
#  'with',
#  'neoclassic',
#  'Mather',
#  'spots',
#  'temporary',
#  'adults',
#  '5',
#  'terrace',
#  'children',
#  'will',
#  'Terms',
#  '1880s',
#  'Savannah',
#  'Town',
#  'platter',
#  'technology',
#  'wildlife',
#  'traffic',
#  'remains',
#  'Southern',
#  'laid',
#  'balcony',
#  'Christmas',
#  'piano',
#  'aviation',
#  'story',
#  'Madison',
#  'face',
#  'vast',
#  'ND',
#  '16',
#  'see',
#  'Eureka',
#  'View',
#  'non',
#  'purchased',
#  'trendy',
#  '241',
#  'Gothic',
#  'details',
#  'Association',
#  'abroad',
#  'showcasing',
#  'designed',
#  'stage',
#  '25th',
#  'vendors',
#  'lies',
#  'district',
#  'The',
#  'CT',
#  'Resting',
#  'cages',
#  'shirts',
#  'readings',
#  'conflicts',
#  'Canada',
#  'North',
#  'Augustine',
#  'long',
#  '3',
#  '6000',
#  'Way',
#  'Side',
#  '9400',
#  '1407',
#  'ancient',
#  'most',
#  'contributors',
#  'chefs',
#  'juices',
#  'Island',
#  'in',
#  'feet',
#  'featured',
#  'House',
#  'Cover',
#  'organization',
#  'community',
#  'Slovenian',
#  'Herb',
#  'WV',
#  'visit',
#  'restore',
#  'takes',
#  'nicknamed',
#  'toys',
#  '200',
#  'permanent',
#  'shows',
#  'archives',
#  'Oval',
#  'time',
#  'contains',
#  'Barbara',
#  'meters',
#  'Corridor',
#  '4101',
#  'stalls',
#  'decades',
#  'Free',
#  'Ritts',
#  'parts',
#  'rare',
#  'snowsuit',
#  'the',
#  'Antonio',
#  'America',
#  'sangria',
#  'cup',
#  'Rock',
#  'happy',
#  'South',
#  '11th',
#  'programs',
#  'playing',
#  'jazz',
#  'Tempe',
#  'occasions',
#  'sculpting',
#  'original',
#  '4408',
#  'source',
#  'This',
#  'play',
#  'About',
#  'others',
#  'feats',
#  'Floyd',
#  '11150',
#  'or',
#  '10',
#  'trams',
#  'Get',
#  'between',
#  'geology',
#  'stocked',
#  'pilots',
#  '60',
#  'Heritage',
#  '7300',
#  'Aquatics',
#  'meals',
#  'Hershey',
#  'comes',
#  'Squire',
#  'aimed',
#  'exploration',
#  'Featured',
#  'Outcalt',
#  'fresh',
#  'Policy',
#  'Built',
#  'run',
#  'giving',
#  'share',
#  'trails',
#  'GMO',
#  'Be',
#  'Music',
#  'wealth',
#  'Santa',
#  'IN',
#  'celebration',
#  'introduces',
#  'Ontario',
#  'corned',
#  'acclaimed',
#  'Created',
#  'Independent',
#  'food',
#  '6',
#  'fields',
#  'counties',
#  'elegant',
#  'shops',
#  'M',
#  'thematic',
#  'Garden',
#  'Alexander',
#  'Reserve',
#  'I',
#  'shop',
#  'white',
#  'Columbus',
#  'Romantic',
#  'wedding',
#  'top',
#  'Czech',
#  'bullpen',
#  'interest',
#  'contributions',
#  'restaurants',
#  'Higbee',
#  'miss',
#  'cheese',
#  'operas',
#  'experience',
#  'programming',
#  'Feature',
#  'presents',
#  'ended',
#  'areas',
#  'works',
#  '503',
#  '618',
#  'important',
#  'Family',
#  'leave',
#  'intimate',
#  '19',
#  'live',
#  'special',
#  'do',
#  '1100',
#  'selected',
#  'Velvet',
#  'Cedar',
#  ...}

# %%
# Remove stop words, get proper nouns
stop_words_set = set(stopwords.words())
tokens = [w for w in tokens if not w in stop_words_set]
proper = pos_tag(tokens)
tokens = [w for w,pos in proper if pos in ['NNP', 'NNPS']]

tokens
# Out:
# ['Lakefront',
#  'School',
#  'Peace',
#  'Boulevard',
#  'Circle',
#  'Berkeley',
#  'CIA',
#  'Zoo',
#  'Möst',
#  'Franz',
#  'Vermont',
#  'Book',
#  'Stories',
#  'UT',
#  'Trips',
#  'Charlottesville',
#  'Marsh',
#  'Tybee',
#  'Programs',
#  'PA',
#  'Boasting',
#  'Maine',
#  'Coral',
#  'Tampa',
#  'Monterey',
#  'TWA',
#  'James',
#  'Committed',
#  'Italy',
#  'Space',
#  'Erieside',
#  'Sunset',
#  'Vacations',
#  'Sanctuary',
#  'Euclid',
#  'Pair',
#  'Caribbean',
#  'Enjoy',
#  'Orchestra',
#  'Ninety',
#  'Wander',
#  'Festival',
#  'Road',
#  'Vienna',
#  'World',
#  'Visit',
#  'Sandusky',
#  'LLC',
#  'Cool',
#  'All',
#  'E',
#  'Canalway',
#  'States',
#  'Raton',
#  'Aiming',
#  'Established',
#  'Park',
#  'Mills',
#  'CA',
#  'Photo',
#  'Greater',
#  'Kenneth',
#  'Major',
#  'Sand',
#  'IWASM',
#  'Vacation',
#  'Building',
#  'Severance',
#  'Carlsbad',
#  'William',
#  'Sadura',
#  'Voted',
#  'Detroit',
#  'Pearl',
#  'Aquarium',
#  'A',
#  'USA',
#  'Avenue',
#  'Chicago',
#  'Places',
#  'GA',
#  'IL',
#  'Lauderdale',
#  'West',
#  'Jennifer',
#  'Erie',
#  'Wildlife',
#  'Cleveland',
#  'Sanibel',
#  'Scottsdale',
#  'Roll',
#  'Search',
#  'Miami',
#  'DE',
#  'Square',
#  'Field',
#  'Golf',
#  'Manakiki',
#  'NH',
#  'Northeast',
#  'Healdsburg',
#  'Egypt',
#  'Rights',
#  'W',
#  'Welser',
#  'Shaped',
#  'Pacific',
#  'Room',
#  'Beaches',
#  'Marble',
#  'Course',
#  'Virginia',
#  'Ford',
#  'OH',
#  'Airport',
#  'Pink',
#  'GE',
#  'Arts',
#  'United',
#  'NC',
#  'Rainforest',
#  'Explore',
#  'Stroll',
#  'Steamship',
#  'Ideas',
#  'Hiking',
#  'SC',
#  'Ave',
#  'Best',
#  'NM',
#  'Gardens',
#  'AICAD',
#  'Taos',
#  'Us',
#  'Drive',
#  'Contemporary',
#  'District',
#  'Lake',
#  'Important',
#  'Timothy',
#  'Don',
#  'Helen',
#  'Point',
#  'Ohio',
#  'Toggle',
#  'VA',
#  'State',
#  'Wilmington',
#  'Mobility',
#  'Suite',
#  'Today',
#  'New',
#  'Contact',
#  'Rated',
#  'JoMo',
#  'Coastal',
#  'Fame',
#  'Rink',
#  'Chagrin',
#  'Tours',
#  'Hawaii',
#  'Ft',
#  'Kids',
#  'MD',
#  'St',
#  'Denver',
#  'Wade',
#  'Waterfalls',
#  'California',
#  'Diego',
#  'T',
#  'Warm',
#  'WI',
#  'CO',
#  'International',
#  'LA',
#  'KY',
#  'Shannon',
#  'Fulton',
#  'Air',
#  'ID',
#  'Atlanta',
#  'Francisco',
#  'Reservation',
#  'Monument',
#  'Wolf',
#  'Hilton',
#  'Studio',
#  'Carrabelli',
#  'Key',
#  'National',
#  'Play',
#  'Girls',
#  'Outlet',
#  'FL',
#  'AL',
#  'thirteen',
#  'Keller',
#  'Minute',
#  'Baseball',
#  'Parkway',
#  'Legends',
#  'Casper',
#  'Berea',
#  'Songs',
#  'Copyright',
#  'KS',
#  'Chandelier',
#  'Progressive',
#  'Byzantine',
#  'Woodstock',
#  'Their',
#  'Anaheim',
#  'Inbox',
#  'Philadelphia',
#  'Indians',
#  'Gianfranco',
#  'Fotolia',
#  'Historic',
#  'MN',
#  'Things',
#  'Assumption',
#  'Service',
#  'Tomasz',
#  'OR',
#  'Residency',
#  'G',
#  'Trek',
#  'Magnolia',
#  'Wedding',
#  'Constructed',
#  'NJ',
#  'Boston',
#  'Randy',
#  'London',
#  'Cemetery',
#  'Campground',
#  'AZ',
#  'Situated',
#  'Story',
#  'Zajda',
#  'Mather',
#  'Savannah',
#  'Town',
#  'Southern',
#  'Christmas',
#  'Madison',
#  'ND',
#  'Eureka',
#  'View',
#  'Gothic',
#  'Association',
#  'CT',
#  'Resting',
#  'Canada',
#  'North',
#  'Augustine',
#  'Way',
#  'Side',
#  'Island',
#  'House',
#  'Cover',
#  'Slovenian',
#  'Herb',
#  'WV',
#  'Barbara',
#  'Corridor',
#  'Free',
#  'Ritts',
#  'Antonio',
#  'America',
#  'Rock',
#  'South',
#  'Tempe',
#  'Get',
#  'Aquatics',
#  'Hershey',
#  'Squire',
#  'Featured',
#  'Outcalt',
#  'Policy',
#  'Built',
#  'GMO',
#  'Be',
#  'Music',
#  'Santa',
#  'IN',
#  'Ontario',
#  'Created',
#  'Independent',
#  'M',
#  'Garden',
#  'Alexander',
#  'Reserve',
#  'Columbus',
#  'Romantic',
#  'Czech',
#  'Higbee',
#  'Family',
#  'Velvet',
#  'Cedar',
#  'Wall',
#  'Europe',
#  'Orleans',
#  'MO',
#  'Hall',
#  'Take',
#  'Africa',
#  'Playhouse',
#  'Natural',
#  'Marti',
#  'Getaways',
#  'Lounge',
#  'Zone',
#  'Indo',
#  'Areas',
#  'Montauk',
#  'Carolina',
#  'Myrtle',
#  'Alternatively',
#  'East',
#  'Apple',
#  'Geneva',
#  'Henryk',
#  'Lakes',
#  'VT',
#  'Wichita',
#  'Courtesy',
#  'Northeastern',
#  'Weekend',
#  'Cold',
#  'MI',
#  'Fine',
#  'Adventure',
#  'Nashville',
#  'Institute',
#  'WA',
#  'Pei',
#  'Harp',
#  'Pix',
#  'From',
#  'Keys',
#  'Home',
#  'Bellflower',
#  'August',
#  'Great',
#  'Prospect',
#  'Me',
#  'Discovery',
#  'Tucson',
#  'Top',
#  'Castle',
#  'TX',
#  'Fun',
#  'VacationIdea',
#  'Comedy',
#  'Joseph',
#  'MOCA',
#  'Malls',
#  'Barrio',
#  'Founded',
#  'Browse',
#  'Ralphie',
#  'Cultural',
#  'Beach',
#  'Burke',
#  'Little',
#  'Portraits',
#  'Workman',
#  'Luxury',
#  'Phone',
#  'Oregon',
#  'Tacos',
#  'Done',
#  'Willoughby',
#  'Later',
#  'Jersey',
#  'Gates',
#  'Bubel',
#  'Florida',
#  'Metroparks',
#  'Juniper',
#  'History',
#  'Guinness',
#  'Day',
#  'LED',
#  'Reef',
#  'Lagoon',
#  'Museum',
#  'Louisville',
#  'Asia',
#  'Northern',
#  'Parker',
#  'Head',
#  'Romanesque',
#  'Newark',
#  'Salt',
#  'City',
#  'Garfield',
#  'Colleges',
#  'Camping',
#  'Read',
#  'Palm',
#  'Parks',
#  'July',
#  'Amusement',
#  'Walks',
#  'San',
#  'Theater',
#  'Tango',
#  'President',
#  'Design',
#  'University',
#  'Boca',
#  'War',
#  'Ship',
#  'Wilderness',
#  'Experience',
#  'ME',
#  'Swim',
#  'Made',
#  'MA',
#  'Village',
#  'Houston',
#  'Reserved',
#  'Nines',
#  'Do',
#  'Allen',
#  'Sponsler',
#  'Sycamore',
#  'African',
#  'Women',
#  'Jamaica',
#  'Elizabeth',
#  'Disclaimer',
#  'RI',
#  'II',
#  'Bakers',
#  'Rivers',
#  'Memorial',
#  'Australian',
#  'Catskills',
#  'Sandstone',
#  'Canton',
#  'Balto',
#  'Privacy',
#  'Giving',
#  'Mayfield',
#  'Visitors',
#  'League',
#  'Roanoke',
#  'Ellensburg',
#  'Doyle',
#  'Picking',
#  'Market',
#  'Flea',
#  'Dallas',
#  'Chadds',
#  'Blossom',
#  'Irish',
#  'Cat',
#  'Brimming',
#  'Phoenix',
#  'Napa',
#  'Street',
#  'Feast',
#  'Georgian',
#  'Dedicated',
#  'George',
#  'Seattle',
#  'Albanian',
#  'True',
#  'Vegas',
#  'Brooklyn',
#  'Pond',
#  'York',
#  'Coast',
#  'Club',
#  'NYC',
#  'Bethesda']

# %% [markdown]
# # Geocoder Autocomplete
#
# Request is for a list of address suggestions for search text.  Can be used interactively as one types to test for a match, or useful for a list of tokens.

# %%
import os
import requests

APP_ID_HERE = os.environ['APP_ID_HERE']
APP_CODE_HERE = os.environ['APP_CODE_HERE']

uri = 'https://autocomplete.geocoder.api.here.com/6.2/suggest.json'
params = {
    'app_id': APP_ID_HERE,
    'app_code': APP_CODE_HERE,
    'query': 'Charlottesville',
}

response = requests.get(uri, params=params)
response.json()
# Out:
# {'suggestions': [{'label': 'United States, VA, Charlottesville (City), Charlottesville',
#    'language': 'en',
#    'countryCode': 'USA',
#    'locationId': 'NT_MkkLiWmx89vadPV8GHcS7D',
#    'address': {'country': 'United States',
#     'state': 'VA',
#     'county': 'Charlottesville (City)',
#     'city': 'Charlottesville',
#     'postalCode': '22902'},
#    'matchLevel': 'city'},
#   {'label': 'United States, VA, Charlottesville (City)',
#    'language': 'en',
#    'countryCode': 'USA',
#    'locationId': 'NT_ItTbwffEBG8czeHHer6OxD',
#    'address': {'country': 'United States',
#     'state': 'VA',
#     'county': 'Charlottesville (City)'},
#    'matchLevel': 'county'},
#   {'label': 'United States, TN, Knoxville, Charlottesville Blvd',
#    'language': 'en',
#    'countryCode': 'USA',
#    'locationId': 'NT_TVDv5q3g8gMfkE2G-CNmyB',
#    'address': {'country': 'United States',
#     'state': 'TN',
#     'county': 'Knox',
#     'city': 'Knoxville',
#     'street': 'Charlottesville Blvd',
#     'postalCode': '37922'},
#    'matchLevel': 'street'},
#   {'label': 'United States, IN, Charlottesville',
#    'language': 'en',
#    'countryCode': 'USA',
#    'locationId': 'NT_uKAbMR2yfxKaeIuwftoxWB',
#    'address': {'country': 'United States',
#     'state': 'IN',
#     'county': 'Hancock',
#     'city': 'Charlottesville',
#     'postalCode': '46117'},
#    'matchLevel': 'city'},
#   {'label': 'United States, NC, Greensboro, Charlottesville Rd',
#    'language': 'en',
#    'countryCode': 'USA',
#    'locationId': 'NT_-hwUL8-IPVeRcbG.L77j7D',
#    'address': {'country': 'United States',
#     'state': 'NC',
#     'county': 'Guilford',
#     'city': 'Greensboro',
#     'district': 'Garriage Hills',
#     'street': 'Charlottesville Rd',
#     'postalCode': '27410'},
#    'matchLevel': 'street'}]}

# %% [markdown]
# # Try It
#
# Parsing street addresses is tricky but give it a try to look for combinations of tokens when combined with autocomplete can help you identify location matches.
